# %%
import pandas as pd
import numpy as np
import random
import itertools
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from mpl_toolkits import mplot3d
# %matplotlib inline

# %% [markdown]
# # Task 1

# %%
housing_data = pd.read_csv("./Housing.csv")
housing_data
# Out:
#        price    area  length  width  bedrooms  bathrooms  stories mainroad  \
# 0    1465896  244316     593    412         4          2        3      yes
# 1    3123904  390488     734    532         4          4        4      yes
# 2    1519896  379974     498    763         3          2        2      yes
# 3    1152112  288028     382    754         4          2        2      yes
# 4     887292  221823     503    441         4          1        2      yes
# ..       ...     ...     ...    ...       ...        ...      ...      ...
# 540   377880  188940     470    402         2          1        1      yes
# 541   483084  241542     497    486         3          1        1       no
# 542   364276  182138     374    487         2          1        1      yes
# 543   734160  367080     570    644         3          1        1       no
# 544  1625268  406317     527    771         3          1        2      yes
#
#     guestroom basement hotwaterheating airconditioning  parking prefarea  \
# 0          no       no              no             yes        2      yes
# 1          no       no              no             yes        3       no
# 2          no      yes              no              no        2      yes
# 3          no      yes              no             yes        3      yes
# 4         yes      yes              no             yes        2       no
# ..        ...      ...             ...             ...      ...      ...
# 540        no      yes              no              no        2       no
# 541        no       no              no              no        0       no
# 542        no       no              no              no        0       no
# 543        no       no              no              no        0       no
# 544        no       no              no              no        0       no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# 3          furnished
# 4          furnished
# ..               ...
# 540      unfurnished
# 541   semi-furnished
# 542      unfurnished
# 543        furnished
# 544      unfurnished
#
# [545 rows x 15 columns]

# %% [markdown]
# ### Univariate ananlysis on column price

# %%
housing_data["price"].mean()
# Out:
# 1058779.8678899081

# %%
housing_data["price"].std()
# Out:
# 667148.2157118551

# %%
housing_data["price"].median()
# Out:
# 907584.0

# %% [markdown]
# # Task 2

# %%
cat_cols = ["mainroad", "guestroom", "basement", "hotwaterheating", "airconditioning", "prefarea", "furnishingstatus"]

housing_data[cat_cols] = housing_data[cat_cols].apply(LabelEncoder().fit_transform)

# %%
cl = DecisionTreeClassifier()
X = housing_data.drop(["furnishingstatus"], axis=1)
y = housing_data["furnishingstatus"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=355)

# %%
# Fit
cl.fit(X_train, y_train)

# Predict
preds = cl.predict(X_test)

# Score
accuracy_score(y_test, preds)
# Out:
# 0.32116788321167883

# %% [markdown]
# # Task 3

# %%
con_cols = ["price", "area"]

# %%
def zero_center_some_thing(column):
    return column - column.mean()

housing_data[con_cols] = housing_data[con_cols].apply(zero_center_some_thing)

# %%
cl = DecisionTreeClassifier()
X = housing_data.drop(["furnishingstatus"], axis=1)
y = housing_data["furnishingstatus"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=355)

# Fit
cl.fit(X_train, y_train)

# Predict
preds = cl.predict(X_test)

# Score
accuracy_score(y_test, preds)
# Out:
# 0.3357664233576642

# %% [markdown]
# # Task 4

# %% [markdown]
# The Normaliztion was a bit helpful

# %% [markdown]
# The accuracy jumped from 31 to 32, that's it

# %% [markdown]
# # Task 5

# %%
lengths = housing_data["length"]
widths = housing_data["width"]
areas = housing_data["area"]

# %% [markdown]
# ### 2D Plot

# %%
fig = plt.figure(figsize=(15, 15))
plt.scatter(lengths, widths, cmap="viridis")
plt.xlabel('House Lengths')
plt.ylabel('House Widths')
plt.title("2D Plot Between Lengths & Widths")
plt.show()

# %% [markdown]
# ### 3D Plot

# %%
fig = plt.figure(figsize=(15, 15))
ax = plt.axes(projection='3d')
ax.scatter3D(lengths, widths, areas)
ax.set_xlabel('House Legths')
ax.set_ylabel('House Wdiths')
ax.set_zlabel('House Areas');

# %% [markdown]
# # Task 6

# %% [markdown]
# ### Covariance

# %%
housing_data.cov()
# Out:
#                          price          area        length         width  \
# price             4.450867e+11  4.583381e+10  4.310565e+07  3.927680e+07
# area              4.583381e+10  1.277520e+10  1.166981e+07  1.106981e+07
# length            4.310565e+07  1.166981e+07  2.200903e+04 -4.514160e+02
# width             3.927680e+07  1.106981e+07 -4.514160e+02  2.090209e+04
# bedrooms          1.653287e+05  2.824302e+03  7.842978e+00 -6.995413e-02
# bathrooms         9.259576e+04  2.429217e+03  3.021725e+00  2.335486e+00
# stories           4.285025e+05 -4.724066e+01  1.111016e+00  7.900702e-01
# mainroad          1.629066e+04 -2.295723e+03 -2.517546e+00 -1.291335e+00
# guestroom         9.679579e+03 -1.698830e+02  1.567701e+00 -2.176825e+00
# basement         -5.499885e+04 -2.791235e+03 -1.345467e+00 -3.605117e+00
# hotwaterheating   1.957561e+03  8.122001e+01 -1.612858e+00  1.537962e+00
# airconditioning   6.979010e+04 -8.024839e+02  6.304496e+00 -6.097865e+00
# parking          -3.175889e+04 -1.217005e+04 -3.987729e+00 -1.666072e+01
# prefarea          2.336708e+03 -2.157056e+03  2.989342e-01 -4.610193e+00
# furnishingstatus -4.932912e+04 -2.169406e+03 -2.131678e-03 -3.953842e+00
#
#                        bedrooms     bathrooms        stories      mainroad  \
# price             165328.693915  92595.758473  428502.452199  16290.657771
# area                2824.302348   2429.217451     -47.240657  -2295.722646
# length                 7.842978      3.021725       1.111016     -2.517546
# width                 -0.069954      2.335486       0.790070     -1.291335
# bedrooms               0.544738      0.138674       0.261589     -0.003096
# bathrooms              0.138674      0.252476       0.142171      0.007427
# stories                0.261589      0.142171       0.752543      0.036809
# mainroad              -0.003096      0.007427       0.036809      0.121546
# guestroom              0.022760      0.024329       0.014460      0.012325
# basement               0.034299      0.024501      -0.071418      0.007326
# hotwaterheating        0.007117      0.007066       0.003424     -0.000860
# airconditioning        0.055140      0.043689       0.118480      0.017097
# parking                0.088562      0.076842       0.034043      0.061407
# prefarea               0.024747      0.013532       0.016352      0.029567
# furnishingstatus      -0.069256     -0.054921      -0.069135     -0.041601
#
#                     guestroom      basement  hotwaterheating  airconditioning  \
# price             9679.578703 -54998.854351      1957.561218     69790.104270
# area              -169.882960  -2791.234822        81.220015      -802.483945
# length               1.567701     -1.345467        -1.612858         6.304496
# width               -2.176825     -3.605117         1.537962        -6.097865
# bedrooms             0.022760      0.034299         0.007117         0.055140
# bathrooms            0.024329      0.024501         0.007066         0.043689
# stories              0.014460     -0.071418         0.003424         0.118480
# mainroad             0.012325      0.007326        -0.000860         0.017097
# guestroom            0.146573      0.068025        -0.000826         0.024609
# basement             0.068025      0.228056         0.000438         0.010517
# hotwaterheating     -0.000826      0.000438         0.043848        -0.012665
# airconditioning      0.024609      0.010517        -0.012665         0.216392
# parking              0.012358      0.021189         0.012244         0.063795
# prefarea             0.026137      0.046216        -0.005279         0.023169
# furnishingstatus    -0.034491     -0.041025        -0.005042        -0.053295
#
#                        parking     prefarea  furnishingstatus
# price            -31758.893497  2336.707555     -49329.123125
# area             -12170.047052 -2157.056024      -2169.406166
# length               -3.987729     0.298934         -0.002132
# width               -16.660719    -4.610193         -3.953842
# bedrooms              0.088562     0.024747         -0.069256
# bathrooms             0.076842     0.013532         -0.054921
# stories               0.034043     0.016352         -0.069135
# mainroad              0.061407     0.029567         -0.041601
# guestroom             0.012358     0.026137         -0.034491
# basement              0.021189     0.046216         -0.041025
# hotwaterheating       0.012244    -0.005279         -0.005042
# airconditioning       0.063795     0.023169         -0.053295
# parking               0.742330     0.033496         -0.116463
# prefarea              0.033496     0.180032         -0.034788
# furnishingstatus     -0.116463    -0.034788          0.579688

# %% [markdown]
# ### Correlation

# %%
housing_data.corr()
# Out:
#                      price      area    length     width  bedrooms  bathrooms  \
# price             1.000000  0.607827  0.435523  0.407210  0.335762   0.276222
# area              0.607827  1.000000  0.695952  0.677425  0.033856   0.042773
# length            0.435523  0.695952  1.000000 -0.021047  0.071629   0.040536
# width             0.407210  0.677425 -0.021047  1.000000 -0.000656   0.032149
# bedrooms          0.335762  0.033856  0.071629 -0.000656  1.000000   0.373930
# bathrooms         0.276222  0.042773  0.040536  0.032149  0.373930   1.000000
# stories           0.740398 -0.000482  0.008633  0.006299  0.408564   0.326165
# mainroad          0.070040 -0.058259 -0.048675 -0.025620 -0.012033   0.042398
# guestroom         0.037897 -0.003926  0.027602 -0.039328  0.080549   0.126469
# basement         -0.172628 -0.051712 -0.018991 -0.052216  0.097312   0.102106
# hotwaterheating   0.014013  0.003432 -0.051918  0.050802  0.046049   0.067159
# airconditioning   0.224880 -0.015263  0.091354 -0.090670  0.160603   0.186915
# parking          -0.055252 -0.124971 -0.031198 -0.133752  0.139270   0.177496
# prefarea          0.008255 -0.044978  0.004749 -0.075153  0.079023   0.063472
# furnishingstatus -0.097114 -0.025209 -0.000019 -0.035919 -0.123244  -0.143559
#
#                    stories  mainroad  guestroom  basement  hotwaterheating  \
# price             0.740398  0.070040   0.037897 -0.172628         0.014013
# area             -0.000482 -0.058259  -0.003926 -0.051712         0.003432
# length            0.008633 -0.048675   0.027602 -0.018991        -0.051918
# width             0.006299 -0.025620  -0.039328 -0.052216         0.050802
# bedrooms          0.408564 -0.012033   0.080549  0.097312         0.046049
# bathrooms         0.326165  0.042398   0.126469  0.102106         0.067159
# stories           1.000000  0.121706   0.043538 -0.172394         0.018847
# mainroad          0.121706  1.000000   0.092337  0.044002        -0.011781
# guestroom         0.043538  0.092337   1.000000  0.372066        -0.010308
# basement         -0.172394  0.044002   0.372066  1.000000         0.004385
# hotwaterheating   0.018847 -0.011781  -0.010308  0.004385         1.000000
# airconditioning   0.293602  0.105423   0.138179  0.047341        -0.130023
# parking           0.045547  0.204433   0.037466  0.051497         0.067864
# prefarea          0.044425  0.199876   0.160897  0.228083        -0.059411
# furnishingstatus -0.104672 -0.156726  -0.118328 -0.112831        -0.031628
#
#                   airconditioning   parking  prefarea  furnishingstatus
# price                    0.224880 -0.055252  0.008255         -0.097114
# area                    -0.015263 -0.124971 -0.044978         -0.025209
# length                   0.091354 -0.031198  0.004749         -0.000019
# width                   -0.090670 -0.133752 -0.075153         -0.035919
# bedrooms                 0.160603  0.139270  0.079023         -0.123244
# bathrooms                0.186915  0.177496  0.063472         -0.143559
# stories                  0.293602  0.045547  0.044425         -0.104672
# mainroad                 0.105423  0.204433  0.199876         -0.156726
# guestroom                0.138179  0.037466  0.160897         -0.118328
# basement                 0.047341  0.051497  0.228083         -0.112831
# hotwaterheating         -0.130023  0.067864 -0.059411         -0.031628
# airconditioning          1.000000  0.159173  0.117382         -0.150477
# parking                  0.159173  1.000000  0.091627         -0.177539
# prefarea                 0.117382  0.091627  1.000000         -0.107686
# furnishingstatus        -0.150477 -0.177539 -0.107686          1.000000

# %% [markdown]
# # Task 7

# %% [markdown]
# ### Correlation of Length and Area

# %%
housing_data["area"].corr(housing_data["length"])
# Out:
# 0.6959524284375517

# %% [markdown]
# ### Plot between Length and Area

# %%
fig = plt.figure(figsize=(12, 12))

plt.scatter(lengths, areas, cmap="viridis")
plt.xlabel("Lengths")
plt.ylabel("Areas")
plt.title("Lengths vs. Areas")
plt.show()

# %% [markdown]
# # Task 8

# %%
# Sample Space of 3 friends going to city A, B, C, D, E
cities = ["A", "B", "C", "D", "E"]
S = [pro for pro in itertools.product(cities, repeat = 3)]
len(S)
# Out:
# 125

# %%
two_person_same_city = [pro for pro in S if (pro[0] == pro[1]) or (pro[0] == pro[2]) or (pro[1] == pro[2])]
len(two_person_same_city)
# Out:
# 65

# %%
prob_two_person_same_city = len(two_person_same_city) / len(S)
prob_two_person_same_city
# Out:
# 0.52

# %%
all_different_cities = [pro for pro in S if (pro[0] != pro[1]) and (pro[1] != pro[2]) and (pro[0] != pro[2])]
len(all_different_cities)
# Out:
# 60

# %%
prob_all_different_cities = len(all_different_cities) / len(S)
prob_all_different_cities
# Out:
# 0.48

# %%
probabilities = [prob_two_person_same_city, prob_all_different_cities]
values = ["2 People Same City", "All Different Cities"]

fig = plt.figure(figsize = (10, 10))

plt.bar(values, probabilities, color ='blue', width = 0.5)
plt.xlabel("Random Variable Values")
plt.ylabel("Probabilies")
plt.title("Probalty Distribution Graph")
plt.show()

# %%
# The Random variable Is Discrete
# It is a TriVariate Problem
